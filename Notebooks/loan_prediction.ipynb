# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\Eng_Ahmed\\projects\\OpenSource\\Notebooks\\dataset\\train.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df[['ApplicantIncome','LoanAmount']]
# Out:
#      ApplicantIncome  LoanAmount
# 0               5849         NaN
# 1               4583       128.0
# 2               3000        66.0
# 3               2583       120.0
# 4               6000       141.0
# ..               ...         ...
# 609             2900        71.0
# 610             4106        40.0
# 611             8072       253.0
# 612             7583       187.0
# 613             4583       133.0
#
# [614 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#handle categorical missing data 
df['Gender'].mode()[0]
# Out:
# 'Male'

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [raw]
# ##EXloratory data analaysis

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\eng_ahmed\envs\myenv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import seaborn as sns
sns.countplot(df['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
sns.countplot(df.Dependents)
# Out:
# <Axes: xlabel='count', ylabel='Dependents'>

# %%
sns.countplot(df.Dependents)
# Out:
# <Axes: xlabel='count', ylabel='Dependents'>

# %%
sns.histplot(df.CoapplicantIncome)
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Count'>

# %%
sns.countplot(df.Married)
# Out:
# <Axes: xlabel='count', ylabel='Married'>

# %%
df['Total_income']=df['ApplicantIncome']+df['CoapplicantIncome']

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  Total_income
# 0             1.0         Urban           Y        5849.0
# 1             1.0         Rural           N        6091.0
# 2             1.0         Urban           Y        3000.0
# 3             1.0         Urban           Y        4941.0
# 4             1.0         Urban           Y        6000.0

# %%
df['ApplicantIncomeLog'] = np.log(df['ApplicantIncome'])

# %%
 sns.histplot(df.ApplicantIncomeLog)
# Out:
# <Axes: xlabel='ApplicantIncomeLog', ylabel='Count'>

# %%
df['CoapplicantIncomeLog'] = np.log(df['CoapplicantIncome'])
sns.distplot(df["ApplicantIncomeLog"])
# Out:
# C:\Users\Eng_Ahmed\Envs\myenv\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Eng_Ahmed\AppData\Local\Temp\ipykernel_7276\817503423.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["ApplicantIncomeLog"])
# <Axes: xlabel='ApplicantIncomeLog', ylabel='Density'>

# %%
df['LoanAmountLog'] = np.log(df['LoanAmount'])
sns.distplot(df['LoanAmountLog'])
# Out:
# C:\Users\Eng_Ahmed\AppData\Local\Temp\ipykernel_7276\3068120744.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LoanAmountLog'])
# <Axes: xlabel='LoanAmountLog', ylabel='Density'>

# %%
df['Loan_Amount_Term_Log'] = np.log(df['Loan_Amount_Term'])
sns.distplot(df['Loan_Amount_Term_Log'])
# Out:
# C:\Users\Eng_Ahmed\AppData\Local\Temp\ipykernel_7276\57442453.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Loan_Amount_Term_Log'])
# <Axes: xlabel='Loan_Amount_Term_Log', ylabel='Density'>

# %%
df['Total_income_Log'] = np.log(df['Total_income'])
sns.distplot(df['Total_income_Log'])
# Out:
# C:\Users\Eng_Ahmed\AppData\Local\Temp\ipykernel_7276\234177728.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total_income_Log'])
# <Axes: xlabel='Total_income_Log', ylabel='Density'>

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  Total_income  ApplicantIncomeLog  \
# 0             1.0         Urban           Y        5849.0            8.674026
# 1             1.0         Rural           N        6091.0            8.430109
# 2             1.0         Urban           Y        3000.0            8.006368
# 3             1.0         Urban           Y        4941.0            7.856707
# 4             1.0         Urban           Y        6000.0            8.699515
#
#    CoapplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  Total_income_Log
# 0                  -inf       4.986426              5.886104          8.674026
# 1              7.318540       4.852030              5.886104          8.714568
# 2                  -inf       4.189655              5.886104          8.006368
# 3              7.765569       4.787492              5.886104          8.505323
# 4                  -inf       4.948760              5.886104          8.699515

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  Total_income  ApplicantIncomeLog  \
# 0             1.0         Urban           Y        5849.0            8.674026
# 1             1.0         Rural           N        6091.0            8.430109
# 2             1.0         Urban           Y        3000.0            8.006368
# 3             1.0         Urban           Y        4941.0            7.856707
# 4             1.0         Urban           Y        6000.0            8.699515
#
#    CoapplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  Total_income_Log
# 0                  -inf       4.986426              5.886104          8.674026
# 1              7.318540       4.852030              5.886104          8.714568
# 2                  -inf       4.189655              5.886104          8.006368
# 3              7.765569       4.787492              5.886104          8.505323
# 4                  -inf       4.948760              5.886104          8.699515

# %%
 cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_income','Loan_ID','CoapplicantIncomeLog']
df = df.drop(columns=cols, axis=1)

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0         Urban           Y            8.674026       4.986426
# 1         Rural           N            8.430109       4.852030
# 2         Urban           Y            8.006368       4.189655
# 3         Urban           Y            7.856707       4.787492
# 4         Urban           Y            8.699515       4.948760
#
#    Loan_Amount_Term_Log  Total_income_Log
# 0              5.886104          8.674026
# 1              5.886104          8.714568
# 2              5.886104          8.006368
# 3              5.886104          8.505323
# 4              5.886104          8.699515

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64

# %%
 df.Education.value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %% [markdown]
# #handling categorical data

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0         Urban           Y            8.674026       4.986426
# 1         Rural           N            8.430109       4.852030
# 2         Urban           Y            8.006368       4.189655
# 3         Urban           Y            7.856707       4.787492
# 4         Urban           Y            8.699515       4.948760
#
#    Loan_Amount_Term_Log  Total_income_Log
# 0              5.886104          8.674026
# 1              5.886104          8.714568
# 2              5.886104          8.006368
# 3              5.886104          8.505323
# 4              5.886104          8.699515

# %%
df.Loan_Status = df.Loan_Status.replace({"Y": 1, "N" : 0})
df.Gender = df.Gender.replace({"Male": 1, "Female" : 0})
df.Married = df.Married.replace({"Yes": 1, "No" : 0})
# Out:
# C:\Users\Eng_Ahmed\AppData\Local\Temp\ipykernel_7276\996336513.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.Loan_Status = df.Loan_Status.replace({"Y": 1, "N" : 0})
# C:\Users\Eng_Ahmed\AppData\Local\Temp\ipykernel_7276\996336513.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.Gender = df.Gender.replace({"Male": 1, "Female" : 0})
# C:\Users\Eng_Ahmed\AppData\Local\Temp\ipykernel_7276\996336513.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.Married = df.Married.replace({"Yes": 1, "No" : 0})

# %%
df.head()
# Out:
#    Gender  Married Dependents     Education Self_Employed  Credit_History  \
# 0       1        0          0      Graduate            No             1.0
# 1       1        1          1      Graduate            No             1.0
# 2       1        1          0      Graduate           Yes             1.0
# 3       1        1          0  Not Graduate            No             1.0
# 4       1        0          0      Graduate            No             1.0
#
#   Property_Area  Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0         Urban            1            8.674026       4.986426
# 1         Rural            0            8.430109       4.852030
# 2         Urban            1            8.006368       4.189655
# 3         Urban            1            7.856707       4.787492
# 4         Urban            1            8.699515       4.948760
#
#    Loan_Amount_Term_Log  Total_income_Log
# 0              5.886104          8.674026
# 1              5.886104          8.714568
# 2              5.886104          8.006368
# 3              5.886104          8.505323
# 4              5.886104          8.699515

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.4.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\eng_ahmed\envs\myenv\lib\site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Using cached scipy-1.13.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.4.2-cp312-cp312-win_amd64.whl (10.6 MB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.8 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.8 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/301.8 kB 186.2 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/301.8 kB 196.9 kB/s eta 0:00:02
#    --------- ----------------------------- 71.7/301.8 kB 302.7 kB/s eta 0:00:01
#    --------------- ---------------------- 122.9/301.8 kB 423.5 kB/s eta 0:00:01
#    --------------------- ---------------- 174.1/301.8 kB 551.6 kB/s eta 0:00:01
#    -------------------------------- ----- 256.0/301.8 kB 682.7 kB/s eta 0:00:01
#    -------------------------------------  297.0/301.8 kB 764.6 kB/s eta 0:00:01
#    -------------------------------------  297.0/301.8 kB 764.6 kB/s eta 0:00:01
#    -------------------------------------- 301.8/301.8 kB 643.7 kB/s eta 0:00:00
# Using cached scipy-1.13.0-cp312-cp312-win_amd64.whl (45.9 MB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.4.2 scipy-1.13.0 threadpoolctl-3.5.0

# %%
from sklearn.preprocessing import LabelEncoder
feature_col = ['Property_Area','Education', 'Dependents','Self_Employed']
le = LabelEncoder()
for col in feature_col:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0              2            1            8.674026       4.986426
# 1              0            0            8.430109       4.852030
# 2              2            1            8.006368       4.189655
# 3              2            1            7.856707       4.787492
# 4              2            1            8.699515       4.948760
#
#    Loan_Amount_Term_Log  Total_income_Log
# 0              5.886104          8.674026
# 1              5.886104          8.714568
# 2              5.886104          8.006368
# 3              5.886104          8.505323
# 4              5.886104          8.699515

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                614 non-null    int64
#  1   Married               614 non-null    int64
#  2   Dependents            614 non-null    int64
#  3   Education             614 non-null    int64
#  4   Self_Employed         614 non-null    int32
#  5   Credit_History        614 non-null    float64
#  6   Property_Area         614 non-null    int64
#  7   Loan_Status           614 non-null    int64
#  8   ApplicantIncomeLog    614 non-null    float64
#  9   LoanAmountLog         614 non-null    float64
#  10  Loan_Amount_Term_Log  614 non-null    float64
#  11  Total_income_Log      614 non-null    float64
# dtypes: float64(5), int32(1), int64(6)
# memory usage: 55.3 KB

# %%
df.describe()
# Out:
#            Gender     Married  Dependents   Education  Self_Employed  \
# count  614.000000  614.000000  614.000000  614.000000     614.000000
# mean     0.817590    0.653094    0.744300    0.218241       0.133550
# std      0.386497    0.476373    1.009623    0.413389       0.340446
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      1.000000    0.000000    0.000000    0.000000       0.000000
# 50%      1.000000    1.000000    0.000000    0.000000       0.000000
# 75%      1.000000    1.000000    1.000000    0.000000       0.000000
# max      1.000000    1.000000    3.000000    1.000000       1.000000
#
#        Credit_History  Property_Area  Loan_Status  ApplicantIncomeLog  \
# count      614.000000     614.000000   614.000000          614.000000
# mean         0.842199       1.037459     0.687296            8.341213
# std          0.349681       0.787482     0.463973            0.645263
# min          0.000000       0.000000     0.000000            5.010635
# 25%          1.000000       0.000000     0.000000            7.964677
# 50%          1.000000       1.000000     1.000000            8.246040
# 75%          1.000000       2.000000     1.000000            8.664750
# max          1.000000       2.000000     1.000000           11.302204
#
#        LoanAmountLog  Loan_Amount_Term_Log  Total_income_Log
# count     614.000000            614.000000        614.000000
# mean        4.862066              5.802065          8.669414
# std         0.496575              0.312482          0.545102
# min         2.197225              2.484907          7.273786
# 25%         4.607658              5.886104          8.334712
# 50%         4.859812              5.886104          8.597205
# 75%         5.104426              5.886104          8.925549
# max         6.551080              6.173786         11.302204

# %%
test = pd.read_csv("C:\\Users\\Eng_Ahmed\\projects\\OpenSource\\Notebooks\\dataset\\test.csv")

# %%
#fill numerical data 
test['LoanAmount'] = test['LoanAmount'].fillna(test['LoanAmount'].mean())
test['Loan_Amount_Term'] = test['Loan_Amount_Term'].fillna(test['Loan_Amount_Term'].mean())
test['Credit_History'] = test['Credit_History'].fillna(test['Credit_History'].mean())

test['Gender'] = test['Gender'].fillna(test['Gender'].mode()[0])
test['Married'] = test['Married'].fillna(test['Married'].mode()[0])
test['Dependents'] = test['Dependents'].fillna(test['Dependents'].mode()[0])
test['Self_Employed'] = test['Self_Employed'].fillna(test['Self_Employed'].mode()[0])

test['Total_income'] = test['ApplicantIncome']+ test['CoapplicantIncome']

#apply log transformation 
test['ApplicantIncomeLog'] = np.log(test['ApplicantIncome'])

test['CoapplicantIncomeLog'] = np.log(test['CoapplicantIncome'])

test['LoanAmountLog'] = np.log(test['LoanAmount'])

test['Loan_Amount_TermLog'] = np.log(test['Loan_Amount_Term'])  

cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_income','Loan_ID','CoapplicantIncomeLog']
test = test.drop(columns=cols, axis=1)


test.Gender = test.Gender.replace({"Male": 1, "Female" : 0})
test.Married = test.Married.replace({"Yes": 1, "No" : 0})

feature_col = ['Property_Area','Education', 'Dependents','Self_Employed']
le = LabelEncoder()
for col in feature_col:
    test[col] = le.fit_transform(test[col])
# Out:
# C:\Users\Eng_Ahmed\Envs\myenv\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Eng_Ahmed\Envs\myenv\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Eng_Ahmed\AppData\Local\Temp\ipykernel_7276\3379476935.py:26: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test.Gender = test.Gender.replace({"Male": 1, "Female" : 0})
# C:\Users\Eng_Ahmed\AppData\Local\Temp\ipykernel_7276\3379476935.py:27: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test.Married = test.Married.replace({"Yes": 1, "No" : 0})

# %%
test.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        1           0          0              0        1.000000
# 1       1        1           1          0              0        1.000000
# 2       1        1           2          0              0        1.000000
# 3       1        1           2          0              0        0.825444
# 4       1        0           0          1              0        1.000000
#
#    Property_Area  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_TermLog
# 0              2            8.651724       4.700480             5.886104
# 1              2            8.031385       4.836282             5.886104
# 2              2            8.517193       5.337538             5.886104
# 3              2            7.757906       4.605170             5.886104
# 4              2            8.094378       4.356709             5.886104

# %%
x = df.drop(columns=['Loan_Status'],axis=1)
y = df['Loan_Status']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test= train_test_split(x,y, test_size=0.25, random_state=42)

# %%
x_train.head()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 92        1        1           2          1              0             1.0
# 304       1        0           0          0              0             1.0
# 68        1        1           3          1              1             1.0
# 15        1        0           0          0              0             1.0
# 211       1        1           3          0              0             0.0
#
#      Property_Area  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  \
# 92               2            8.093462       4.394449              5.886104
# 304              0            8.294050       4.941642              5.886104
# 68               2            8.867850       4.828314              4.094345
# 15               2            8.507143       4.828314              5.886104
# 211              1            8.140316       4.852030              5.886104
#
#      Total_income_Log
# 92           8.535622
# 304          8.779557
# 68           8.867850
# 15           8.507143
# 211          8.451053

# %%
y_test.head()
# Out:
# 350    1
# 377    1
# 163    1
# 609    1
# 132    1
# Name: Loan_Status, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print("Accuracy is", model.score(x_test,y_test)*100)
# Out:
# Accuracy is 79.22077922077922

# %%
import pickle
file = open("model.pkl", 'wb')
pickle.dump(model, file)
